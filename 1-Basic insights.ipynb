# %% [markdown]
# In this notebook we get the following insights from Amazon Review Data (2018):
# 1. Price of Products <br>
# 2. Price of product per category <br>
# 3. Review Rate of Products <br>
# 4. The most rated product across(price, brand, category) with different combinations

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.3)

# %%
from pyspark import SparkContext
from itertools import product
import json
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_PATH = '/content/drive/Shareddrives/CIE/BigData_Final_Project/Data'
RESULTS_PATH = '/content/drive/Shareddrives/CIE/BigData_Final_Project/Results'

# %%
# create Spark context with necessary configuration
sc = SparkContext("local","FinalProject")

# %% [markdown]
# ### Price of Products

# %%
def product_price(line):
  # The function maps each json line into a key, value pair of (product_ID, price) 
  line = json.loads(line)  #load json object
  matched = re.match('\$\d+\.\d{2}', line['price']) #Check for the correct price format using regex matching
  if matched:
    return (line['asin'], matched.group(), line['title']) # Mapping each line to (product_ID, price)
  return (line['asin'], '', line['title'])

# Read the data as text file;
# Filter the price with regex matching
# sort by price ascendingly
productPrice = sc.textFile(DATA_PATH + "/meta").map(product_price)\
              .filter(lambda x:re.match('^\$\d+\.\d{2}', x[1]))\
              .sortBy(lambda x:float(x[1][1:]))
productPrice.saveAsTextFile(RESULTS_PATH+"/ProductPricewithName") # Save Output as text file

# %%
productPrice.take(2)
# Out:
# [('045122261X', '$0.96', 'In the Blood (The Darkwing Chronicles, Book 4)'),
#  ('0594451647',
#   '$1.46',
#   'Barnes &amp; Noble HDTV Adapter Kit for NOOK HD and NOOK HD+')]

# %% [markdown]
# ### Price of product per category

# %%
def product_price_category(line): 
  # This function maps each object into (category, (product_ID, price))
  line = json.loads(line)
  result = []
  matched = re.match('\$\d+\.\d{2}', line['price'])  #Check for the correct price format using regex matching
  if matched:
    for category in line['category']:
      # For each category this product underlies, a (category, (product_ID, price)) is returned
      result.append((category, (line['asin'], matched.group(),line['title']))) 
    return result
  return [('cat', (line['asin'], '*', line['title']))]  # If no matching price is there, and empty line is returned
# Read data as text files, and maps each object into (category, (product_ID, price))
# Group by category
# Sort the list of products in each category ascendingly according to their price
productPriceCategory = sc.textFile(DATA_PATH+"/meta").flatMap(product_price_category)\
                       .filter(lambda x:re.match('\$\d+\.\d{2}', x[1][1])).groupByKey()\
                       .mapValues(lambda x:sorted(list(x),key=lambda y:float(y[1][1:])))
productPriceCategory.saveAsTextFile(RESULTS_PATH+"/ProductPriceCategorywithName") # Save output as text file

# %%
productPriceCategory.take(1)
# Out:
# [('Electronics',
#   [('045122261X', '$0.96', 'In the Blood (The Darkwing Chronicles, Book 4)'),
#    ('0594451647',
#     '$1.46',
#     'Barnes &amp; Noble HDTV Adapter Kit for NOOK HD and NOOK HD+'),
#    ('9512089130',
#     '$1.48',
#     'Black Label Bag SX-70 Polaroid Two Compartment Pouch Compatible with Instax'),
#    ('1059844575',
#     '$1.54',
#     'SlimPort sli44532 Adapter for LG G3 Smartphone MyDP/Micro-USB to HDMI Adapter Connects Any MyDP Enabled Mobile Device and Play Content to Any HDTV or HDMI Enabled Device, Black'),
#    ('1059999102',
#     '$1.54',
#     'SlimPort Adapter for LG G Pad 8.3 Tablet, MyDP/Micro-USB to HDMI Adapter Connects Any MyDP Enabled Mobile Device and Play Content to Any HDTV or HDMI Enabled Device, Black'),
#    ('9573213893',
#     '$1.54',
#     'Dell Latitude E6420 E6430 E6430s E6320 E6330 DVD-RW Drive w/Faceplate &amp; caddy'),
#    ('9573213877',
#     '$1.54',
#     'Dell Latitude E4200, E4300, E5400, E6320 E6420 E6520 E6400, E6430 E6500 Precision M2400, M4400, M6400 External E-Sata DVD-RW Drive'),
#    ('9573213842',
#     '$1.54',
#     'MOTOROLA ML900 Laptop/Notebook CD-RW/DVD COMBO drive HKUN4002A'),
#    ('193187302X', '$1.67', 'FRENCH in 10 minutes a day with CD-ROM'),
#    ('1842556851', '$1.80', 'Emily Windsnap: A Tangle of Tails'),
#    ('8867320939',
#     '$1.90',
#     'Moleskine Pens/Reading Glasses Case, Cadmium Orange (6 X 1.5 X 1.25)'),
#    ('0594033896', '$1.96', 'Nook Color Clear Screen Protector Kit 2-Pack'),
#    ('1434799387', '$1.96', 'Wounded: A Love Story'),
#    ('1615513353',
#     '$1.96',
#     'Barnes &amp; Noble for Nook 1st Edition Wi-fi + 3G Industriell Cover'),
#    ('0887234674', '$1.99', "Bottom Line's Power Aging"),
#    ('098339752X', '$2.07', 'THE FAN LETTER'),
#    ('0758238401', '$2.78', 'The Wolf Prince'),
#    ('1560276533', '$2.95', 'Pilot Logbook: ASA-SP-10'),
#    ('0758225199', '$2.99', 'The Shadow Guard'),
#    ('0786672641', '$2.99', 'Mel Bay Gig Savers: Killer Turnarounds'),
#    ('0314185550',
#     '$3.00',
#     'BARBRI First Year Review 2008 Edition (F 08 S 09)'),
#    ('0312364415', '$3.25', 'A Stranger Lies There'),
#    ('1616263288',
#     '$3.43',
#     'Love Me Back to Life (Circle of Friends (Barbour))'),
#    ('1450257895', '$3.74', 'The Chinese Conspiracy'),
#    ('1394860919',
#     '$3.92',
#     'Mini Display Port to VGA Cable Adapter for Monitor/Projector to Macbook Air/Pro'),
#    ('0594450659',
#     '$3.95',
#     'AntiGlare Screen Film Kit for NOOK HD Anti-glare screen protection 7"'),
#    ('1593592108',
#     '$3.95',
#     'PINK iLITE BOOK LIGHT (Kindle) (3rd Gen LED Bulb) (Booklight Series)'),
#    ('1593592086',
#     '$3.95',
#     'Blue iLite: 3rd Generation Technology (Booklight Series)'),
#    ('0312171048', '$3.98', 'The Angel Doll: A Christmas Story'),
#    ('7204079302',
#     '$3.98',
#     'DB9 Female / DB9 Female Molded Gender Changer Adapter'),
#    ('0812566564', '$3.99', 'Greenhouse Summer'),
#    ('5891109654',
#     '$3.99',
#     'OBiDi - USB 2.0 A Female To Micro B 5 Pin Male Plug Adapter Converter'),
#    ('0578030500', '$4.31', 'Running in the Rain'),
#    ('7503689404',
#     '$4.46',
#     'New Nikula Zoom Mini Monocular Telescope 7x18mm Black'),
#    ('6575464564',
#     '$4.49',
#     'GW Security 2.1MP Sony CMOS 130 Degree Fisheye Lens Wide Angle Dome Indoor CCTV HD-CVI /TVI/AHD/960H 1200TVL 4-in-1 HD 1080P Camera'),
#    ('1934931519', '$4.71', 'Turning Technologies QT Device RCQR-01'),
#    ('3744295508',
#     '$4.72',
#     'Advanced High Speed Digital 6 feet Hdmi 24k Gold Sealed Connector Cable'),
#    ('059403390X',
#     '$4.73',
#     'Barnes &amp; Noble BP-01-C01-N2-1 Industriell Cover'),
#    ('0091912407',
#     '$4.76',
#     'Girl with a One-track Mind: Confessions of the Seductress Next Door'),
#    ('7564005068', '$4.85', 'DB9 Male / DB9 Female Null Modem Mini Adapter'),
#    ('5891092824',
#     '$4.87',
#     'OBiDi - 10m mini camera self-timer wireless bluetooth remote shutter for IOS Android camera 360 iphone5 5S ipad Galaxy S5 S4 Note III'),
#    ('0575075996',
#     '$4.95',
#     'The Runes of the Earth : The Last Chronicles of Thomas Covenant'),
#    ('1842232983', '$4.97', 'The Trouble with Weddings'),
#    ('0385666535', '$4.98', 'Incidents in the Life of Markus Paul'),
#    ('106171330X',
#     '$4.99',
#     'Professional Ultra SanDisk 64GB MicroSDXC GoPro HERO4 Silver / Surf card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1061603105',
#     '$4.99',
#     'Professional Ultra SanDisk 32GB MicroSDHC Garmin Dash Cam 10 card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1061791017',
#     '$4.99',
#     'Professional Ultra SanDisk 128GB MicroSDXC works with Samsung Galaxy S5 Active International card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1880688336',
#     '$4.99',
#     'Verbatim CDR 650MB 74MIN Media 16x (1-Pack with Jewel Case) (Discontinued by Manufacturer)'),
#    ('7510416752', '$4.99', 'The Weather with You (Chinese Edition)'),
#    ('7507825604',
#     '$5.05',
#     'Bargain Cable DB9 Female / DB9 Female Null Modem Mini Adapter'),
#    ('0972277153', '$5.10', 'Not With My Son'),
#    ('188745618X', '$5.11', 'America, A Christian Nation?'),
#    ('1606480197', '$5.23', 'Chasing Smoke'),
#    ('1600883044', '$5.29', 'Lunar Mates'),
#    ('8866139807', '$5.44', 'Moleskine 9788866139805 13-Inch Laptop Case'),
#    ('1932172378', '$5.49', 'Liberty Rising'),
#    ('5891046709',
#     '$5.49',
#     'OBiDi - Piggy Style Soft Silicone Case for Apple iPod Touch 5 - Green'),
#    ('0151014841', '$5.79', 'Lady Lazarus'),
#    ('1416593535', '$5.82', 'Bad Traffic: A Novel'),
#    ('0615294553', '$5.89', 'Shmirshky: think inside the box'),
#    ('1449908357', '$5.89', 'Falling Star'),
#    ('0758213832', '$5.98', 'With You And Without You'),
#    ('0786296151', '$5.99', 'Summer Breeze (Four Seasons)'),
#    ('1060606852',
#     '$5.99',
#     'Professional Ultra SanDisk 64GB MicroSDXC Samsung Galaxy SX card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('0981688438', '$6.00', 'Seven Blessings of the Atonement'),
#    ('7793224531',
#     '$6.00',
#     'Monster Equivalent HDMI 1000HD Ultra-High Speed HDMI Cable (2 meters) (NON-OEM/GENERIC)'),
#    ('0594459451',
#     '$6.04',
#     'Barnes &amp; Noble Nook Color Tablet USB Cable Charger Newest Re-enforced Version'),
#    ('1464742979', '$6.08', 'Leisure Arts-Animal Lovies'),
#    ('1413752985', '$6.15', 'Baring It All'),
#    ('2059620007',
#     '$6.40',
#     'Orange Sources 20 CCTV BNC Crimp on Security System Camera Connector Adapter RG59/62 Coax'),
#    ('0976385805',
#     '$6.44',
#     'Technology Challenged: Understanding Our Creations &amp; Choosing Our Future'),
#    ('1935557726',
#     '$6.53',
#     'Kindred Spirits: Four Hundred Years of an American Family'),
#    ('1444700650', '$6.59', 'Nightfall'),
#    ('8432204773',
#     '$6.82',
#     'Conversacion en la catedral / Conversation in the Cathedral (Spanish Edition)'),
#    ('105997231X',
#     '$6.85',
#     'Motorola DROiD MAXX POWERED (OTG) Micro-USB to USB 2.0 Adapter High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go with Power Port!'),
#    ('6073894996',
#     '$6.91',
#     'SANOXY High Output Dual USB Port Car Charger for Ipad, Samsung Galaxy, Iphone, Blackberry, Droid, Gps, and Other Tablets, Smart Phones and High Powered Devices'),
#    ('1059950073',
#     '$6.95',
#     'Verizon Wireless Ellipsis 7 POWERED (OTG) Micro-USB to USB 2.0 Adapter High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go with Power Port!'),
#    ('1401302319', '$6.95', 'The Yummy Mummy'),
#    ('1059998254',
#     '$6.98',
#     'Samsung Galaxy Tab 4 10.1 (OTG) Micro-USB to USB 2.0 Right Angle Adapter for High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go! (Black)'),
#    ('0375505458',
#     '$7.00',
#     'A Collection of Beauties at the Height of Their Popularity: A Novel'),
#    ('2253136530',
#     '$7.09',
#     'Claude Gueux (Le Livre De Pouche) (French Edition)'),
#    ('1450559883', '$7.30', 'Sleepwalker: The Last Sandman'),
#    ('1060106795',
#     '$7.46',
#     'Premium LG G Pad 7.0 Tablet Stylus Custom Pen 3 Pack!'),
#    ('1060103036',
#     '$7.46',
#     'Premium Dell Venue 8 Pro Tablet Stylus Custom Pen 3 Pack!'),
#    ('1060100231',
#     '$7.47',
#     'Premium AT&amp;T Avail 2 SmartPhone Stylus Custom Pen 3 Pack!'),
#    ('1060104342',
#     '$7.47',
#     'Premium Asus MeMO Pad HD 7 Tablet Stylus Custom Pen 3 Pack!'),
#    ('1060301040',
#     '$7.47',
#     'Premium BlueAnt Q2 Voice-Controlled Pure Conversation Bluetooth Headset Stylus Custom Pen 3 Pack!'),
#    ('1060102048',
#     '$7.47',
#     'Premium Acer iconia A1-830 Tablet Stylus Custom Pen 3 Pack!'),
#    ('0976272032', '$7.55', 'The Lonely Kid'),
#    ('1849164053', '$7.85', 'The Upright Piano Player'),
#    ('1593592116',
#     '$7.91',
#     'PURPLE iLITE BOOK LIGHT (Kindle) (3rd Gen LED Bulb) (Booklight Series)'),
#    ('1593592094',
#     '$7.98',
#     'CLEAR iLITE BOOK LIGHT (Kindle) (3rd Gen LED Bulb) (Booklight Series)'),
#    ('0132492776',
#     '$7.99',
#     'Wireless Bluetooth Headphones Earbuds with Microphone in Ear Headphones Noise Cancelling Earbuds with Mic Sweatproof Bluetooth Earphones Stereo Headset for Running Workout Gym Sports Secure Fit Case'),
#    ('059454582X',
#     '$7.99',
#     'Groovy Stand in Crimson Color For Barnes &amp; Noble NOOK HD 9780594545828'),
#    ('0983597405',
#     '$7.99',
#     'Influence for Impact: Increasing Your Effectiveness in Your Organization'),
#    ('1061790827',
#     '$7.99',
#     'Professional Ultra SanDisk 128GB MicroSDXC Samsung Galaxy Note IV card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1061790878',
#     '$7.99',
#     'Professional Ultra SanDisk 128GB MicroSDXC Samsung Galaxy Note 4 Verizon card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('4126895493',
#     '$7.99',
#     'HeadGear 3.5mm Foldable Headphone Headset for Dj Headphone Mp3 M Pc Tablet Music Video and All Other Music Playersp (Green)'),
#    ('1841957941', '$8.00', 'The Bullet Trick'),
#    ('1123000034',
#     '$8.14',
#     'NB-1LH NB-1L BATTERY for CANON Powershot S100 S400 S500 S200 NB-1LH, Digital ELPH'),
#    ('0765312506', '$8.25', 'The Lost Van Gogh'),
#    ('1059997649',
#     '$8.55',
#     'LG G Pad 7.0 (OTG) Micro-USB to USB 2.0 Right Angle Adapter for High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go! (Black)'),
#    ('1061792870',
#     '$8.55',
#     'Samsung Galaxy Avant (OTG) Micro-USB to USB 2.0 Right Angle Adapter for High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go! (Black)'),
#    ('1059996367',
#     '$8.77',
#     'Alcatel OneTouch PIXI 7 (OTG) Micro-USB to USB 2.0 Right Angle Adapter for High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go! (Black)'),
#    ('1059998173',
#     '$8.77',
#     'Samsung Galaxy Note 4 (OTG) Micro-USB to USB 2.0 Right Angle Adapter for High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go! (Black)'),
#    ('1060101424',
#     '$8.77',
#     'Premium LG G Pad 8.3 Tablet Stylus Custom Pen 3 Pack!'),
#    ('1060304694',
#     '$8.77',
#     'Premium Huawei MediaPad 10 FHD SmartPhone Stylus Custom Pen 3 Pack!'),
#    ('1577553667', '$8.89', "Webster's Pocket Dictionary and Thesaurus"),
#    ('1254875778',
#     '$8.95',
#     'Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600S 1333MHz HMT325S6BFR8C-H9'),
#    ('1406925845',
#     '$8.95',
#     "Little Wars; a game for boys from twelve years of age to one hundred and fifty and for that more intelligent sort of girl who likes boys' games and books."),
#    ('0545105668', '$8.97', 'Elephant Run'),
#    ('0594017580', '$8.99', 'Jonathan Adler Punctuation Cover in Black'),
#    ('1452885052', '$8.99', 'God: A Long Time Ago in a Galilean Far, Far Away'),
#    ('6465354276',
#     '$8.99',
#     'New Style 8GB Crystal Diamond Red Violin Style USB Flash Drive with Keychain'),
#    ('0966295749', '$9.00', 'God Unlimited'),
#    ('3902217138', '$9.00', 'Lomography London Notebook [Office Product]'),
#    ('0786719664', '$9.02', 'A Load of Old Bones'),
#    ('0380812916', '$9.07', 'Tokyo Suckerpunch : A Billy Chaka Adventure'),
#    ('0782494285',
#     '$9.36',
#     'Thinking Gifts Folding Booklight, Blue, 1 unit (FOBL1)'),
#    ('1445286483', '$9.39', 'Whirl of the Wheel'),
#    ('1061793745',
#     '$9.55',
#     'Samsung Galaxy S6 (OTG) Micro-USB to USB 2.0 Right Angle Adapter for High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go! (Black)'),
#    ('3744295478',
#     '$9.62',
#     'Mobile Excess ADVANCED HIGH SPEED DIGITAL 10 FT HDMI 24k GOLD SEALED CONNECTOR CABLE !'),
#    ('1059723875',
#     '$9.77',
#     'Travel Amazon Kindle Fire HDX 7 Tablet Wall Charger is digitally controlled for Fast Acting Charging, Slim, and Completely Portable! (BLACK / 1 Amp)'),
#    ('1059838095',
#     '$9.77',
#     'Travel Kodak PLAYTOUCH Zi10 Video Camera Wall Charger is digitally controlled for Fast Acting Charging, Slim, and Completely Portable! (BLACK / 1 Amp)'),
#    ('105998055X',
#     '$9.77',
#     'LG G2 mini POWERED (OTG) Micro-USB to USB 2.0 Adapter High Speed Data-Transfer Cable for connecting any compatible USB Accessory/Device/Drive/Flash/ and truly On-The-Go with Power Port!'),
#    ('1060188821',
#     '$9.77',
#     'Travel Alcatel OneTouch POP 7 Tablet Wall Charger is digitally controlled for Fast Acting Charging, Slim, and Completely Portable! (BLACK / 1 Amp)'),
#    ('1060186993',
#     '$9.77',
#     'Travel LG G Pad 7.0 Tablet Wall Charger is digitally controlled for Fast Acting Charging, Slim, and Completely Portable! (BLACK / 1 Amp)'),
#    ('3442461030', '$9.87', 'Phantom'),
#    ('0375503757', '$9.90', 'What She Saw...: A Novel'),
#    ('1460992482', '$9.95', 'The Great Adventures of Thomas Trumpet'),
#    ('8032458719', '$9.95', 'AMBIT SWITCHING ADAPTER DSA-12R-12 AUS'),
#    ('3490204816',
#     '$9.97',
#     'Orange Sources 3MP IP Camera Onvif 4mm Lens POE IR 90ft HD Video 20481536 Outdoor Day/ Night'),
#    ('0594481953', '$9.99', 'Hd+ Screen Protector Kit- Nook'),
#    ('0594514681', '$9.99', 'Hd Groovy Stand In Blue- Nook'),
#    ('073530498X', '$9.99', 'Vintage Camera Photo Album'),
#    ('0984612742', '$9.99', 'Love Me'),
#    ('1419659332', '$9.99', 'When Destinies Meet'),
#    ('1432704869', '$9.99', 'Predators of Darkness'),
#    ('1450537537', '$9.99', 'The Prague Deception'),
#    ('1456334484', '$9.99', 'Flip a House Today'),
#    ('2338500822',
#     '$9.99',
#     'Micron 2GB DDR3 Laptop Memory Ram PC3-8500S MT8JSF25664HZ-1G1D1'),
#    ('6000007469',
#     '$9.99',
#     'KLIC-8000 Charger for Kodak EasyShare Z1012IS Z1085IS'),
#    ('6000007388',
#     '$9.99',
#     'KLIC-7004 Battery Charger For Kodak EasyShare V1253'),
#    ('074361111X',
#     '$10.12',
#     'Florida West Coast and the Keys Chart Book - Maptech ChartKit Book w/Companion CD'),
#    ('8805002097',
#     '$10.20',
#     'Professional LED Video Light Panel with Barn Doors 40W 4500LM Dimmable Continuous Output Lighting Studio 48CH 6 Groups 2.4GHz CRI 95 1-100% Brightness 5600K Color Filter'),
#    ('0805447512', '$10.28', 'Seeing Things: A Novel'),
#    ('6000008775',
#     '$10.31',
#     'NP-BK1 NPBK1 Type K Li-ion Battery Charger For Sony DSC'),
#    ('1059131625',
#     '$10.47',
#     'Slim Amazon Kindle Fire HDX 7 Tablet Standard LED Wall Home Charger! AC / 110V-240V (Black)'),
#    ('1059133954',
#     '$10.47',
#     'Slim Verizon Wireless Ellipsis 7 Tablet Standard LED Wall Home Charger! AC / 110V-240V (Black)'),
#    ('0974204498', '$10.55', 'Critical and Creative Thinking for Teenagers'),
#    ('1608612112', '$10.63', 'Worldwide Ward Secret Recipes'),
#    ('1463567774', '$10.79', 'Yoke: The Bound Trilogy Book I'),
#    ('0983440700', '$10.99', 'Beneath the Dune'),
#    ('1451567804', '$11.00', 'The Caldera Incident'),
#    ('1935009257',
#     '$11.19',
#     'The Original Mighty Bright MiniFlex Clip On Book Light Reading Light, 1 Bright White LED, Flexible, Durable, Compact Design Perfect For Bookworms, Kids, Read in Bed, 25 Hour Battery Life (Blue)'),
#    ('0060009810', '$11.49', 'One Hot Summer'),
#    ('2020000008',
#     '$11.75',
#     'Orange Sources 20Pcs/Pack CCTV Security System Camera BNC Female to RCA Male Connector 2OC'),
#    ('0971614504', '$11.95', 'Shade of the Maple'),
#    ('0982888422', '$11.99', 'The Translated Man and Other Stories'),
#    ('1463553943', '$11.99', 'Irrefutable'),
#    ('1935009036', '$11.99', 'Mighty Bright 40451 XtraFlex Book Light, Blue'),
#    ('1935009044', '$11.99', 'Mighty Bright XtraFlex Book Light, Silver'),
#    ('1935009354', '$11.99', 'Mighty Bright 42616 TravelFlex Book Light, Pink'),
#    ('1456372246', '$12.00', 'Metro-Line to Murder'),
#    ('1905512694', '$12.00', 'Killing Mum'),
#    ('1560271434', '$12.34', 'The Standard Pilot Log (ASA-SP-30)'),
#    ('7801641795',
#     '$12.50',
#     '72 DISC Capacity CD Wallet for CD, DVD, Blu-Ray Media Storage, Nylon CD Holder, Black / Grey'),
#    ('0312331363', '$12.78', 'Scared Money'),
#    ('1935009192', '$12.79', 'Mighty Bright 84312 2-LED USB Light, Silver'),
#    ('0578040069', '$12.87', 'Colonnade: A Life In Columns'),
#    ('1857546563', '$12.88', 'Selected Writings: William Tyndale'),
#    ('059448426X',
#     '$12.95',
#     'Composition Cover For Barnes &amp; Noble Nook HD+ in Black 9780594484264'),
#    ('144579179X', '$12.95', 'Inner Space Book One'),
#    ('1453707727', '$12.95', 'Our Family of Foods'),
#    ('1453867996', '$12.95', 'Four Years from Home'),
#    ('1560273267', '$12.95', 'The Standard Engine Log: ASA-SE-2'),
#    ('0615456685', '$12.97', 'Stay: A Callie Rose Novel'),
#    ('106171327X',
#     '$12.99',
#     'Sandisk SDSDQUA-064G-A11 Professional Ultra 64GB MicroSDXC card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec) for GoPro HERO4 Black'),
#    ('1452891435', '$12.99', 'The Last Bartender'),
#    ('1495443043', '$12.99', 'Country Heaven (Dare River)'),
#    ('1841566942',
#     '$12.99',
#     'Nova Development FKWT Photo Explosion Deluxe 4.0'),
#    ('1890238449', '$12.99', 'Blackbeard, Terror of the Seas'),
#    ('193500929X',
#     '$12.99',
#     'The Original Mighty Bright MiniFlex Clip On Book Light Reading Light, 1 Bright White LED, Flexible, Durable, Compact Design Perfect For Bookworms, Kids, Read in Bed, 25 Hour Battery Life (Black)'),
#    ('1933745525',
#     '$13.05',
#     'Learning Advantage Equivalent Fraction Dominoes: Lowest Terms, Common Denominators, Sums of One'),
#    ('8172610130', '$13.21', 'A Cup of Tea'),
#    ('1451529082', '$13.23', 'Concrete Underground'),
#    ('161235128X', '$13.46', 'Proposition'),
#    ('0151004714', '$13.81', 'The Last Life: A Novel'),
#    ('096789171X', '$13.91', 'X10 Home Security System'),
#    ('1893687643', '$13.91', 'Prophecy of Swords'),
#    ('0060786817', '$13.95', 'sex.lies.murder.fame.: A Novel'),
#    ('0749938978', '$13.95', 'Star Gazing'),
#    ('9507321187',
#     '$13.96',
#     'La Reina en el Palacio de las Corrientes de Aire'),
#    ('0977939812', '$13.99', 'Red Moon'),
#    ('1572600020', '$13.99', 'Ultimate Einstein                    C/Win/Ww'),
#    ('0743400054',
#     '$14.00',
#     'Callisto Volume 1 (The Classic Science Fiction Fantasy Series)'),
#    ('1434890465', '$14.00', 'Snow Ball: A Novel By April L. Hamilton'),
#    ('2059500001',
#     '$14.00',
#     'Orange Sources 20Pcs/Pack CCTV BNC RG59 Male Security System Camera COMPRESSION CONNECTOR 5OC'),
#    ('1348510390',
#     '$14.08',
#     'Replacement Keyboard for Toshiba Satellite C650 C655 C660 C665 L750 L770'),
#    ('1456775146',
#     '$14.41',
#     'The Smyrna Corner: An Epic Tale of Money, Love &amp; Politics Set in the Crumbling Ottoman Empire on the Eve of World War I'),
#    ('1874167001',
#     '$14.62',
#     "Charts for Colour Knitting a Designer's Source Book From the Personal Collection of Alice Starmore"),
#    ('9573212919', '$14.86', 'External USB DVD/CD'),
#    ('0594477670',
#     '$14.95',
#     'Barnes &amp; Noble NOOK Color &amp; Tablet Anti-Glare Screen Protector Film Kit'),
#    ('0615337546', '$14.95', 'The Lifelong Project'),
#    ('1411684338', '$14.95', 'The Official How To Rap Manual'),
#    ('1432765027', '$14.95', 'Christmas Eve Can Kill You'),
#    ('1434844226',
#     '$14.95',
#     'Shadow of the Thunderbird (Cryptids Trilogy, Book 1)'),
#    ('1439204063',
#     '$14.95',
#     'Behind the Housing Crash: Confessions from an Insider'),
#    ('1461189454', '$14.95', 'The Overtaking: (The Overtaking Series)'),
#    ('1587153440',
#     '$14.95',
#     'The Counterfeit Heinlein (Gerald Knave Science Fiction Novels)'),
#    ('1601870485',
#     '$14.95',
#     'The Yellow Violet (Rue Morgue Classic British Mysteries)'),
#    ('1929519028', '$14.95', 'The Touch'),
#    ('1938945018',
#     '$14.95',
#     '100 Days of Blessing - Volume 2: Devotions for Wives and Mothers'),
#    ('1062562690',
#     '$14.99',
#     'Professional Kingston 16GB MicroSDHC Card for Samsung Galaxy S6 with custom formatting and Standard SD Adapter! (Class 4)'),
#    ('1182702627',
#     '$14.99',
#     'Bluetooth Headphones, Bluetooth V4.1+EDR Wireless Headphones HD Stereo Noise Canceling Sweatproof Sport Earphones for Most Smartphones, Samsung S9/S9p/S8 Note 8/7'),
#    ('1434840980', '$14.99', 'The Cyber Miracles'),
#    ('1440499101', '$14.99', 'The Armageddon Conspiracy'),
#    ('1460911385', '$14.99', 'Crossroads'),
#    ('1461049725', '$14.99', 'The Twin Prophecies: Rebirth'),
#    ('1463564643', '$14.99', 'Crooked Branch'),
#    ('1581247281', '$14.99', 'Miles to Go Before I Sleep'),
#    ('8805002003',
#     '$14.99',
#     '70 LED Rechargeable Photo Studio Light Video Camera Camcorder Photography Lamp'),
#    ('0811865126',
#     '$15.95',
#     'CD Packaging Kit - Candy Orchards: DIY: Turn Your Music and Photo CDs Into Instant Gifts'),
#    ('1453813373',
#     '$15.95',
#     'Creation Story Reader: Big Letter Books for Children'),
#    ('1876315245', '$15.95', 'Sound Therapy: Music to Recharge your Brain'),
#    ('886527221X', '$15.98', 'Wicca Seal'),
#    ('0983405816', '$15.99', 'Darkness &amp; Light'),
#    ('1609319745', '$16.00', 'Shakespeare SHZP03 She is Fierce Zipper Pouch'),
#    ('0594513316', '$16.36', 'Nook HD Black Seaton Cover'),
#    ('1542967929',
#     '$16.38',
#     'Cognitive Behavioral Therapy: Mastery- How to Master Your Brain &amp; Your Emotions to Overcome Depression, Anxiety and Phobias (Cognitive Behavioral Therapy Series) (Volume 2)'),
#    ('0679730427', '$16.44', 'Aspects of Love'),
#    ('0984117555',
#     '$16.95',
#     "The Jumper Chronicles: The Quest for Merlin's Map"),
#    ('1379178304',
#     '$16.95',
#     'Yellowstone River Basin and Adjacent Coal Area Level B Study: Report and Environmental Assessment: 8a'),
#    ('1934144762', '$16.95', 'The Mile High Club'),
#    ('1615527656', '$16.99', 'Barnes &amp; Noble Lewes Quote e-Reader Cover'),
#    ('1413728383', '$17.00', "Double Forte': A Gus LeGarde Mystery"),
#    ('1892738473', '$17.18', 'Fresh Air'),
#    ('8866139874', '$17.40', 'Moleskine Rechargeable Booklight, Black'),
#    ('1933622326',
#     '$17.59',
#     'Mighty Bright 44812 The HammerHead Light, Silver'),
#    ('1618541110', '$17.80', 'Gleim - Remote Pilot Knowledge Test'),
#    ('0981540716',
#     '$17.90',
#     "Lynched: A Conservative's Life on a New York City School Board"),
#    ('1591332958', '$17.95', 'The House of the Sphinx'),
#    ('0446697192', '$17.99', 'Hollywood Is like High School with Money'),
#    ('1935009311', '$18.49', 'Mighty Bright 42611 TravelFlex Book Light, Blue'),
#    ('0671793969', '$18.67', 'Love, Stars, And All That'),
#    ('1060608413',
#     '$18.76',
#     'Professional Ultra SanDisk 16GB MicroSDHC LG VS880 card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1061513777',
#     '$18.76',
#     'Professional Ultra SanDisk 16GB MicroSDHC Samsung Galaxy S5 Active card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1060608405',
#     '$18.76',
#     'Professional Ultra SanDisk 16GB MicroSDHC LG G Vista card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('106196258X',
#     '$18.77',
#     'Professional Ultra SanDisk 16GB MicroSDHC Samsung Galaxy Note PRO 12.2 Developers Edition card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1438977247', '$18.95', 'Mad Man'),
#    ('1616855711',
#     '$18.95',
#     'Barnes &amp; Noble Nook 2nd Edition Oliver Cover Black/Cream'),
#    ('184923888X', '$18.99', 'Who Got Liz Gardner'),
#    ('0857201182',
#     '$19.04',
#     "The Registrar's Manual for Detecting Forced Marriages"),
#    ('1426945841', '$19.56', 'Sudden Moves: A Young Adult Mystery'),
#    ('1933305975', '$19.88', 'Essential Painkiller Jane'),
#    ('1607860058',
#     '$19.93',
#     'Garmin GPSMAP 196 Qref Checklist (Qref Avionics Quick Reference)'),
#    ('1935009281', '$19.95', 'Mighty Bright 42514 MiniFlex Book Light, Green'),
#    ('0446576476', '$19.99', 'Plenty Good Room'),
#    ('1061512711',
#     '$19.99',
#     'Professional Kingston 32GB MicroSDHC Card for Samsung SM-T310 with custom formatting and Standard SD Adapter! (Class 4)'),
#    ('1404305955', '$19.99', 'The Golf Course Mystery'),
#    ('1436394058', '$19.99', 'Friends 2 Lovers'),
#    ('1591962749',
#     '$19.99',
#     'Horror Rules: The Simply Horrible Roleplaying Game'),
#    ('161685572X', '$19.99', 'Barnes &amp; Noble Nook Oliver Cover, Red'),
#    ('9178909457', '$19.99', 'IKEA - KOPPLA 6 Outlet Power Bar With Switch X2'),
#    ('0984106820', '$20.18', 'Green Diet'),
#    ('0965321002', '$20.19', 'A Small Percentage (Small Percentage, 1)'),
#    ('1903155800', '$20.80', 'The Winds of Heaven'),
#    ('0727868721', '$21.35', 'The Price of Liberty'),
#    ('270210620X', '$21.64', 'Flashman'),
#    ('1061962210',
#     '$21.77',
#     'Professional Ultra SanDisk 16GB MicroSDHC Samsung Galaxy S5 Sport International card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1607864177', '$21.94', 'Piper Archer II PA-28-181 Qref Checklist Book'),
#    ('1103932454', '$21.99', 'The Modern Siren'),
#    ('1935443062', '$22.00', "Boy's Club #3"),
#    ('1615527672', '$22.49', 'Barnes Noble 5010490303 Lautner e-Reader Cover'),
#    ('1607860457',
#     '$22.52',
#     'Garmin GPSMAP 195 Qref Checklist (Qref GPS Quick Reference)'),
#    ('1607864266', '$22.94', 'Cessna 150 Qref Checklist Book'),
#    ('1613380224', '$22.95', 'Indonesian New Testament'),
#    ('0899425690',
#     '$22.99',
#     'Black Leather Zipper Case for Missals, Liturgy of the Hours and Prayer Books'),
#    ('1607864274', '$22.99', 'Cessna 152 Qref Checklist Book'),
#    ('1932685707',
#     '$23.53',
#     "Mike Holt's Workbook to Accompany Understanding the NEC Volume 1 2011 Edition"),
#    ('2264053518',
#     '$23.95',
#     "Le cercle littraire des amateurs d'pluchures de patates (French Edition)"),
#    ('1933550724', '$23.98', 'Keynes the Man'),
#    ('8866133051', '$24.08', 'Moleskine Shell Small Cerulean Blue'),
#    ('0976162601',
#     '$24.46',
#     '3-D Explosion : Simply Fabulous Art Quilt Illusions by Cara Gulati (2004-05-03)'),
#    ('0968211828',
#     '$24.95',
#     'Batteries in a Portable World: A Handbook on Rechargeable Batteries for Non-Engineers, Second Edition'),
#    ('1413761054', '$24.95', "The Kaua'i Obake Bar: A Primo's Talk Story Book"),
#    ('1480338761',
#     '$24.95',
#     'OEUVRES POUR GUITARE - GUITAR WORKS I - SOLO GUITAR'),
#    ('0557689759', '$24.99', 'Lamb of God: New American Gospel'),
#    ('1931171823', '$25.00', 'How to Free-Form Crochet 8745331'),
#    ('1681983389',
#     '$25.31',
#     "David Busch's Canon EOS Rebel SL2/200D Guide to Digital SLR Photography"),
#    ('160786004X',
#     '$25.90',
#     'Garmin GPSMAP 296 Qref Checklist (Qref Avionics Quick Reference)'),
#    ('1613380216', '$25.95', 'Serbian Bible'),
#    ('1612231888', '$26.99', 'Golden Age of Flight 2017 Deluxe Wall Calendar'),
#    ('1577346785', '$27.36', 'A Time for the Heart: A Novel'),
#    ('1061603261',
#     '$27.46',
#     'Professional Ultra SanDisk 32GB MicroSDHC GoPro HERO4 SILVER card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1062062418',
#     '$27.46',
#     'Professional Ultra SanDisk 32GB MicroSDHC Samsung Galaxy S5 Sprint card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1607864169', '$27.94', 'Piper Cherokee 140 PA-28-140 Qref Book'),
#    ('1741859379', '$28.11', 'Simply Drawing Book &amp; DVD'),
#    ('0764207474', '$28.58', 'Not a Sparrow Falls'),
#    ('1598116541', '$28.59', 'Abinadi'),
#    ('0747566763', '$28.64', 'Last Tango in Aberystwyth'),
#    ('0743608801',
#     '$29.95',
#     'Maptech Waterproof Maps: Puget Sound, Number 100'),
#    ('1607860074',
#     '$29.95',
#     'Garmin GNS 430 Qref Checklist (Qref Avionics Quick Reference)'),
#    ('0594484332',
#     '$29.99',
#     'Groovy Stand For Barnes &amp; Noble Nook HD in Orange 9780594484332'),
#    ('1615527648', '$29.99', 'Barnes &amp; Noble Emerson Quote e-Reader Cover'),
#    ('8866133019', '$29.99', 'Moleskine 9788866133018 eReader Shell - Black'),
#    ('8867320890', '$29.99', 'Moleskine Rechargeable Booklight, Magenta'),
#    ('0974008664', '$31.49', "Forever David's"),
#    ('0575074205', '$32.17', 'Fat (Gollancz)'),
#    ('1594145865', '$32.85', 'Dunston Falls (Five Star First Edition Mystery)'),
#    ('0385671539', '$32.95', 'Natural Order'),
#    ('059449771X',
#     '$34.88',
#     'Barnes &amp; Noble Replacement Charging Sync Cable for Nook HD and HD+ (5 Feet)'),
#    ('0972683275',
#     '$34.99',
#     'VideoSecu 24" Long Arm TV Wall Mount Low Profile Articulating Full Motion Cantilever Swing Tilt wall bracket for most 22" to 55" LED LCD TV Monitor Flat Screen VESA 200x200 400x400 up to 600x400mm MAH'),
#    ('1484782224',
#     '$34.99',
#     'Clementine Series (8 Book Box Set) [Includes seven chapter books and the &quot;Clementine All About You Journal&quot;]'),
#    ('198347598X',
#     '$35.00',
#     'Professional PHP: Building maintainable and secure applications'),
#    ('1601800940', '$37.33', 'Demoness'),
#    ('8866139815', '$37.52', 'Moleskine 9788866139812 10-Inch Laptop Case'),
#    ('075253744X', '$38.62', 'Classic Spooky Stories'),
#    ('1062162854',
#     '$38.70',
#     'Professional Ultra SanDisk 64GB MicroSDXC Google Nexus 6 Unlocked card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1062062434',
#     '$38.77',
#     'Professional Ultra SanDisk 32GB MicroSDHC Samsung Galaxy S5 Verizon card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('0739402226', '$39.00', 'Comes the Dark'),
#    ('194424283X', '$39.00', 'The Surfing Animals Alphabet'),
#    ('706176516X',
#     '$39.95',
#     '4) New Renegade RX52 5.25&quot; 320 Watt 2-Way Car Audio Coaxial Speakers Stereo'),
#    ('097079844X',
#     '$41.04',
#     "Slaves, Salt, Sex &amp; Mr. Crenshaw: The Real Story of the Old Slave House and America's Reverse Underground R.R."),
#    ('071803936X',
#     '$42.48',
#     'JESS TE LLAMA (Spanish Edition) (Spanish) Imitation Leather'),
#    ('1847281087', '$42.99', 'How to Host your own Web Server'),
#    ('1062162420',
#     '$43.76',
#     'Professional Ultra SanDisk 64GB MicroSDXC Samsung Galaxy S5 ATT card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('0957456808', '$45.00', 'Geometric Beadwork (Volume 1)'),
#    ('1857235835',
#     '$45.60',
#     'To Green Angel Tower Storm (Memory, Sorrow &amp; Thorn)'),
#    ('8866139793', '$45.74', 'Moleskine 9788866139799 15-Inch Laptop Case'),
#    ('0743610911', '$47.38', 'Maptech Long Island Sound WPB032504'),
#    ('0303532572',
#     '$48.99',
#     'TDK Hi8 MP120 Premium Performance Camcorder Videotape (6-pack)'),
#    ('6123015451',
#     '$51.99',
#     'Portable Photography Background Backdrop Stand Kit: 10x8-1/5'),
#    ('3283005737',
#     '$52.54',
#     'Google Glass Explorer Edition(XE) Version 2.0 (Charcoal)'),
#    ('1060607093',
#     '$54.47',
#     'Professional Ultra SanDisk 64GB MicroSDXC Sony PlayStation Portable 3000 Series card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1060808404',
#     '$54.47',
#     'Professional Ultra SanDisk 64GB MicroSDXC LG G Vista card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1061713474',
#     '$54.47',
#     'Professional Ultra SanDisk 64GB MicroSDXC Samsung SM-T310 card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('0743611098', '$54.95', 'Maptech CGFL-05 Embassy Cruising Guide Florida'),
#    ('0743610881',
#     '$54.95',
#     'Maptech Waterproof Chartbook: Hudson River and New York Harbor'),
#    ('0932647332', '$54.95', 'Buzzards Bay, South Cape &amp; the Islands'),
#    ('1615527613', '$58.88', 'Barnes &amp; Noble BN-ADP-H01 Power Kit'),
#    ('8439711654', '$63.29', 'Memoria de mis putas tristes [Hardcover]'),
#    ('0011300000',
#     '$65.00',
#     'Genuine Geovision 1 Channel 3rd Party NVR IP Software with USB Dongle Onvif PSIA'),
#    ('6185553554',
#     '$69.00',
#     'Trimble TDS TSC2 AC Wall Charger, OEM Factory Power Supply'),
#    ('276460131X', '$72.44', 'Le Gout Du Bonheur Floerent'),
#    ('1931177007', '$78.89', 'T-Model Tommy'),
#    ('8706513239',
#     '$82.39',
#     'Rockford Fosgate R2D4-10 10" 500 Watt 4-Ohm DVC Subwoofer + Vented Enclosure'),
#    ('8862936826',
#     '$84.18',
#     'Moleskine Folio Digital Tablet Cover for Apple iPad'),
#    ('4454678758',
#     '$85.68',
#     'GENUINE Respironics MW115RA1200N05 AC Power Supply Charger Adapter'),
#    ('1400699169',
#     '$89.55',
#     'Barnes &amp; Noble NOOK HD+ Tablet 32GB Slate (BNTV600-32GB)'),
#    ('9512089157',
#     '$99.00',
#     'Black Label Bag Half-case for Leica M4, M6, M7, and MP'),
#    ('1848414889',
#     '$99.95',
#     'Sony PRS-600 Touch Edition Digital E-Book Reader'),
#    ('8791321689',
#     '$122.00',
#     '2) New Rockford Fosgate R152-S 5.25&quot; 80W + 2) R165-S 6.5&quot; 80W Component Speakers'),
#    ('8867326678', '$122.74', 'Moleskine myCloud Backpack- Moss Green'),
#    ('8065642683',
#     '$130.79',
#     'Boss R3400D 3400W Mono Block Class D Car Amplifier + Remote + 1/0 Gauge Amp Kit'),
#    ('1061791556',
#     '$167.88',
#     'Professional Ultra SanDisk 128GB MicroSDXC Google Nexus 6 64GB card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('1061791548',
#     '$167.88',
#     'Professional Ultra SanDisk 128GB MicroSDXC Google Nexus 6 32GB card is custom formatted for high speed, lossless recording! Includes Standard SD Adapter. (UHS-1 Class 10 Certified 30MB/sec)'),
#    ('8498383188', '$181.26', 'el ultimo encuentro ( bolsillo )'),
#    ('1323549889',
#     '$395.00',
#     'The Premium Cisco CCNA Home Lab Kit 1-Year Warranty'),
#    ('8172763387',
#     '$499.96',
#     'The Wisdom Of Thirukkural/A Guide To Living-A Commentary')])]

# %% [markdown]
# ### Review Rate of Products

# %%
def review(line):
  # This function maps the reviewed products, to be used to count the reviews of each product
  line = json.loads(line)
  return line['asin']
# Read data as text file, and get the product_ids in the review dataset
reviews = sc.textFile(DATA_PATH+"/reviews").map(review)
# word count the presence of each product_ID (asin)
productCount = reviews.map(lambda product: (product, 1)).reduceByKey(lambda a,b:a +b).cache()
# Sorting the products from most reviewed to least, and save the output in a text file
productCount.sortBy(lambda x:x[1],ascending=False).saveAsTextFile(RESULTS_PATH+"/ProductReviewCount")

# %% [markdown]
# ### The average overall rating of each product, sort them by value, to get the most rated product across(price, brand, category)

# %%
def product_rating(line):
  # This function maps the overall rating of each producs as (product_ID, overall_rating)
  line = json.loads(line)
  return (line['asin'], line['overall'])
# Read the review data as a text file, get the (product_ID, overall_rating), then add the value of ratings of a product
productRating = sc.textFile(DATA_PATH+"/reviews").map(product_rating).reduceByKey(lambda a,b:a +b)
# Getting the average rating by joining the number of reciews of a product, with overall_rating sum and getting the avg
productAvgRating = productRating.join(productCount).mapValues(lambda val: round(val[0]/val[1],2)).cache()

# %%
def mapping_group(value):
  # This function is a helper function to map the list to be sorted, according to rating 
  def sorting_key(x):
    # The sorting key function to be used by sort function
    return x[1][1]
  value.sort(key=sorting_key, reverse=True) # Sorting the list descendingly according to rating
  return value

# %%
def myround(x, base=50):
    # This helper function is used to put the prices in ranges of 50
    return base * round(x/base)

# %% [markdown]
# 1. Across the price

# %%
def product_price(line):
   #This function is to map each product object into (product_ID, price)
  line = json.loads(line)
  matched = re.match('\$\d+\.\d{2}', line['price']) #Check for the correct price format using regex matching
  if matched:
    price = "$"+str(myround(float(matched.group()[1:])))+".00"
    return (line['asin'], price, line['title'])
  return (line['asin'], '', line['title'])
# Read the data as text file;
# Filter the price with regex matching
productPrice = sc.textFile(DATA_PATH+"/meta").map(product_price).filter(lambda x:re.match('\$\d+\.\d{2}', x[1]))
# Joining the output with average rating of each product, sorting with price ascendingly, then group by the price
# For each price range (ranges of 50$), a list of products for each price range is sorted accoding to overall_rating
priceRatings = productPrice.join(productAvgRating).sortBy(lambda x:x[1][1]).groupBy(lambda x:x[1][0])\
                           .mapValues(list).mapValues(mapping_group)
priceRatings.saveAsTextFile(RESULTS_PATH+"/PriceRatingSynergy")  #Saving output as text file

# %%
priceRatings.take(2)
# Out:
# [('$0.00',
#   [('0312331363', ('$0.00', 5.0)),
#    ('0578040069', ('$0.00', 5.0)),
#    ('0060009810', ('$0.00', 4.71)),
#    ('0545105668', ('$0.00', 4.69)),
#    ('0312171048', ('$0.00', 4.62)),
#    ('0594459451', ('$0.00', 4.54)),
#    ('0446576476', ('$0.00', 4.44)),
#    ('0446697192', ('$0.00', 3.93)),
#    ('0060786817', ('$0.00', 3.67)),
#    ('0151004714', ('$0.00', 3.58)),
#    ('0380812916', ('$0.00', 3.55)),
#    ('0375503757', ('$0.00', 3.38)),
#    ('0375505458', ('$0.00', 3.17))])]

# %% [markdown]
# 2. Category

# %%
def product_category(line): 
  # This function maps each product as (product_ID,category)
  line = json.loads(line)
  result = []
  for category in line['category']:
    # For each category this product underlies, a ((product_ID, category)) is returned
    result.append((line['asin'], category))
  return result
# read data as text files, and map each product as (product_ID,category)
productCategory = sc.textFile(DATA_PATH+"/meta").flatMap(product_category)
# The result is joined with the average rating of each product, then grouped by the Category
# For each category, the list of products is sorted descendingly according to their average overall rating
categoryRatings = productCategory.join(productAvgRating).groupBy(lambda x:x[1][0])\
                                 .mapValues(list).mapValues(mapping_group)
categoryRatings.saveAsTextFile(RESULTS_PATH+"/CategoryRatingsSynergy") # Saving output as text file

# %% [markdown]
# 3. Brand

# %%
def product_brand(line): 
  # This function maps each product as (product_ID,brand)
  line = json.loads(line)
  return (line['asin'], line['brand'])
# read data as text files, and map each product as (product_ID,brand)
productBrand = sc.textFile(DATA_PATH+"/meta").map(product_brand)
# The result is joined with the average rating of each product, then grouped by the Brand
# For each category, the list of products is sorted descendingly according to their average overall rating
brandRatings = productBrand.join(productAvgRating).groupBy(lambda x:x[1][0])\
                           .mapValues(list).mapValues(mapping_group)
brandRatings.saveAsTextFile(RESULTS_PATH+"/BrandRatingsSynergy")  # Saving output as text file

# %% [markdown]
# ### The average overall rating of each product, sort them by value, to get the most rated product across(price, category)

# %%
def product_price_categories(line):
  # This function maps each product as (product_ID,price,[list of categories]) 
  line = json.loads(line)
  matched = re.match('\$\d+\.\d{2}', line['price'])  #Check for the correct price format using regex matching
  if matched:
    return (line['asin'], (matched.group(), [category for category in line['category']]))
  return (line['asin'], ('*', []))
def flatenning_category(x):
  # This function puts the combinctions of each category and so differnt categories of each product are considered
  # The input value is in the form (price, [list of categories], rating)
  # The output value is (price, category, rating) for each category in the list
  return [comb for comb in product([x[0][0]],x[0][1],[x[1]])]
def categorical_prices_rating(line):
  # This function is a simple maping function to put the category as the key
  result = []
  for tuple in line[1]:
    result.append((tuple[1], (line[0], tuple[0], tuple[2])))
  return result
# Read data as text files
productPrice = sc.textFile(DATA_PATH+"/meta").map(product_price_categories)\
                .filter(lambda x:re.match('\$\d+\.\d{2}', x[1][0]))
# The result of (product_ID,price,[list of categories]) is joined with the average rating of each product
# Which is then mapped to split the list of categories using the flatenning fuction
# The result is then grouped by the category, andwithin each category the list of products is sorted by rating
categoryPriceRating = productPrice.join(productAvgRating).mapValues(flatenning_category)\
                                  .flatMap(categorical_prices_rating).groupByKey()\
                                  .mapValues(lambda x:sorted(list(x),key=lambda y:float(y[1][1:])))
categoryPriceRating.saveAsTextFile(RESULTS_PATH+"/CategoryPriceRatingwithPrice") # Save output as text files

# %% [markdown]
# ### The average overall rating of each product, sort them by value, to get the most rated product across(price, brand)

# %%
def product_price_brand(line): 
  # This function maps each product as ((product_ID,(price,brand))
  line = json.loads(line)
  return (line['asin'], (line['price'], line['brand']))
def mapping_line(line):
  # This helper function is used to redistribute each line to put the brand as the key
  return (line[1][0][1], (line[0],line[1][0][0],line[1][1]))
# read data from text files, map each product as ((product_ID,(price,brand)), 
productPriceBrand = sc.textFile(DATA_PATH+"/meta").map(product_price_brand)\
                      .filter(lambda x:re.match('\$\d+\.\d{2}', x[1][0]))
#The result of ((product_ID,(price,brand)) is joined with the average rating
# The result is grouped by the brand, and sorted ascendingly according to the Price
brandPriceRating = productPriceBrand.join(productAvgRating).map(mapping_line).groupByKey()\
                                    .mapValues(lambda x:sorted(list(x),key=lambda y:y[1]))
brandPriceRating.saveAsTextFile(RESULTS_PATH+"/BrandPriceRatingwithPrice") # Save output as text file
